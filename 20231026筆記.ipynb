# %% [markdown]
# <a href="https://colab.research.google.com/github/vcdemy/20231026/blob/main/20231026%E7%AD%86%E8%A8%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 20231026筆記
#
# <pre>
# # 20231026筆記
# </pre>

# %% [markdown]
# ## 變數命名
#
# <pre>
# ## 變數命名
# </pre>

# %%
x = 1

# %%
x
# Out:
# 1

# %%
# 變數會區分大小寫
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5209e0109617> in <cell line: 2>()
#       1 # 變數會區分大小寫
# ----> 2 X
#
# NameError: name 'X' is not defined

# %%
# 變數開頭不能為數字
3abc = 1
# Out:
#   File "<ipython-input-4-7fd472fbf9ce>", line 2
#     3abc = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
_3abc = 1

# %%
for = 1
# Out:
#   File "<ipython-input-6-b26be1b49601>", line 1
#     for = 1
#         ^
# SyntaxError: invalid syntax

# %%
變數 = 123

# %%
變數
# Out:
# 123

# %% [markdown]
# ## 基本資料型態
#
# * int
# * float
# * bool
# * str

# %% [markdown]
# ### int

# %%
x = 1

# %%
type(x)
# Out:
# int

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
m = 4
n = 2

# %%
type(m / n)
# Out:
# float

# %%
m / n
# Out:
# 2.0

# %%
# 整數除法
m // n
# Out:
# 2

# %%
4 // 2
# Out:
# 2

# %%
3 // 2
# Out:
# 1

# %%
3.0 // 2
# Out:
# 1.0

# %% [markdown]
# ### float (浮點數)

# %%
p = 1.23

# %%
type(p)
# Out:
# float

# %% [markdown]
# ### bool (布林變數)

# %%
3 > 2
# Out:
# True

# %%
z = 3 > 2

# %%
type(z)
# Out:
# bool

# %%
m == n
# Out:
# False

# %%
z = m == n

# %%
type(z)
# Out:
# bool

# %% [markdown]
# ### str (字串)

# %%
u = dog
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-75ef8b645079> in <cell line: 1>()
# ----> 1 u = dog
#
# NameError: name 'dog' is not defined

# %%
u = "dog"

# %%
type(u)
# Out:
# str

# %%
v = 'dog'

# %%
u == v
# Out:
# True

# %%
u = "It's my dog!"

# %%
v = 'It\'s my dog!'

# %%
u == v
# Out:
# True

# %% [markdown]
# ## 使用Pillow做圖形處理

# %% [markdown]
# ### 讀取圖檔

# %%
from PIL import Image

# %%
img = Image.open('lin03.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x670>

# %% [markdown]
# ### 顯示圖檔資訊

# %%
img.size
# Out:
# (1024, 670)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.format
# Out:
# 'JPEG'

# %% [markdown]
# ### 彩色轉單色

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1024x670>

# %% [markdown]
# ### 圖形存檔

# %%
img.convert('L').save('lin01.jpg')

# %% [markdown]
# ## Gradio使用簡介

# %%
# !pip install gradio

# %%
import gradio as gr

# %%
def process01(image):
  return image

# %%
gr.Interface(process01, "pil", "pil").launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://11c87765f1e20cd3c2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://11c87765f1e20cd3c2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def process02(image):
  return image.convert('L')

# %%
gr.Interface(process02, "pil", "pil").launch()

# %%
import random

def process03(image):
  image.save(f"{random.randint(0, 99999):05}.jpg")
  return image.convert('L')

# %%
gr.Interface(process03, "pil", "pil").launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://74a3727705930123f7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://74a3727705930123f7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 基本容器型別
#
# * list
# * tuple
# * dict
# * set

# %% [markdown]
# ### list
